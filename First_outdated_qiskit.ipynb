# %%
from qiskit import *
from qiskit.visualization import plot_histogram
# %matplotlib inline

# %%
import qiskit_aer

# %%
from qiskit_aer import Aer

# %%
qr = QuantumRegister(1)
cr = ClassicalRegister(1)
circuit = QuantumCircuit(qr, cr)
circuit.h(qr)
circuit.measure(qr, cr)

# %% [markdown]
# outdated code

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend=simulator, shots=1024).result()
plot_histogram(result.get_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 simulator = Aer.get_backend('qasm_simulator')
# ----> 2 result = execute(circuit, backend=simulator, shots=1024).result()
#       3 plot_histogram(result.get_counts())
#
# NameError: name 'execute' is not defined

# %% [markdown]
# code that works

# %%
backend = Aer.get_backend('qasm_simulator')

# Simulate the circuit
result = backend.run(circuit, shots=102400).result()
plot_histogram(result.get_counts())

# %%
print(result.get_counts())
# Out:
# {'1': 51304, '0': 51096}
